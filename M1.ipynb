# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# Eventually, for Anaconda warnings.
# Can be commented out.
import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
# Load basic libraries
import seaborn; seaborn.set()
import pickle, copy, json
import numpy as np
import scipy.stats
from sklearn.metrics import make_scorer, confusion_matrix
from sklearn.model_selection import cross_val_score, RandomizedSearchCV, train_test_split
from sklearn.externals import joblib
from sklearn_crfsuite import scorers, metrics
import sklearn_crfsuite
from multiprocessing import Pool

# %%
# Load dataset
data = json.load(open('dataset/annotated_dataset.json')) # remember to unzip it!
report = pickle.load(open("dataset/report.p", "rb"))

# %%
# number of documents (wither monographs or journal issues), with annotations
print(len(data))
# Out:
# 340

# %%
for r,v in report.items():
    print(r+ " : "+str(v))
# Out:
# total_general_m : 11360
# avg annotated docs over total docs : 0.2476397966594045
# total_specific : 157768
# total_general : 41071
# total_annotations : 198839
# overall_documents : 1377
# total_general_per_class_nofilter : {'meta-annotation': 6587, 'secondary-partial': 17306, 'primary-full': 4055, 'primary-partial': 3591, 'secondary-full': 16447}
# avg annotated pages per annotated doc : 16.994134897360702
# avg annotated pages over total pages : 0.029432229688206284
# total_specific_per_class : defaultdict(<class 'int'>, {'note': 710, 'volume': 4740, 'archivalfond': 440, 'abbreviation': 4713, 'century': 10, 'conjunction': 3131, 'curator': 1, 'topicdate': 23, 'editor': 3263, 'folder': 598, 'foliation': 1549, 'parte': 231, 'publicationnumber-year': 2583, 'series': 577, 'year': 316, 'cedola': 9, 'box': 1782, 'table': 75, 'codex': 908, 'date': 3449, 'column': 412, 'period': 27, 'other': 344, 'mazzo': 23, 'publicationyear': 14477, 'archivalunit': 442, 'fascicolo': 251, 'pagination': 18055, 'numbering': 4044, 'tomo': 730, 'notary': 192, 'abbreviatedtitle': 3987, 'archivalseries': 354, 'attachment': 1028, 'publisher': 3777, 'fond': 6, 'publicationplace': 13925, 'archive': 3252, 'library': 735, 'responsible': 12, 'registry': 1351, 'parchment': 59, 'citation': 11, 'chapter': 182, 'publicationspecifications': 1502, 'cartulation': 2662, 'filza': 488, 'protocollo': 18, 'author': 22245, 'voce': 81, 'publicationnumber': 892, 'title': 27051, 'archivalreference': 5880, 'website': 6, 'appendix': 159})
# positive_results : 1
# total_general_per_class_j : {'meta-annotation': 4219, 'secondary-partial': 11328, 'primary-full': 3943, 'primary-partial': 3131, 'secondary-full': 7090}
# total_general_per_class_m : {'meta-annotation': 2367, 'secondary-partial': 2183, 'primary-full': 111, 'primary-partial': 457, 'secondary-full': 6242}
# total_general_j : 29711
# total_general_per_class : {'meta-annotation': 6586, 'secondary-partial': 13511, 'primary-full': 4054, 'primary-partial': 3588, 'secondary-full': 13332}

# %%
# example of contents in the annotated dataset
data[10]
# Out:
# {'bid': 'CFI0056764',
#  'doc_number': '',
#  'doc_type': 'monograph',
#  'pages': {'2': {'is_annotated': True,
#    'offsets': [[['L.', 20, 21, 3, 2, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'author', 'b', 'b-secondary-full']],
#     [['Balsamo,', 23, 30, 4, 2, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'author', 'i', 'i-secondary-full']],
#     [['Giovanti’Angelo', 32, 46, 5, 2, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['Scinzenzeler', 48, 59, 6, 2, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['tipografo', 62, 70, 7, 3, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['in', 72, 73, 8, 3, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['Milano', 75, 80, 9, 3, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['(1500-1526),', 82, 93, 10, 3, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['Fi-', 95, 97, 11, 3, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publicationplace', 'i', 'i-secondary-full']],
#     [['renze,', 100, 105, 12, 4, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publicationplace', 'i', 'i-secondary-full']],
#     [['Sansoni', 107, 113, 13, 4, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publisher', 'i', 'i-secondary-full']],
#     [['1959.', 115, 119, 14, 4, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publicationyear', 'e', 'e-secondary-full']],
#     [['L.', 122, 123, 15, 5, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'author', 'b', 'b-meta-annotation']],
#     [['Balsamo,', 125, 132, 16, 5, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'author', 'i', 'i-meta-annotation']],
#     [['I', 134, 134, 17, 5, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['primi', 136, 140, 18, 5, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['corsivi,', 142, 149, 19, 5, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['in:', 151, 153, 20, 5, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', '', 'i', 'i-meta-annotation']],
#     [['L.', 155, 156, 21, 5, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'author', 'i', 'i-meta-annotation']],
#     [['Bal-', 158, 161, 22, 5, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'author', 'i', 'i-meta-annotation']],
#     [['samo', 164, 167, 23, 6, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'author', 'i', 'i-meta-annotation']],
#     [['-', 169, 169, 24, 6, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'author', 'i', 'i-meta-annotation']],
#     [['A.', 171, 172, 25, 6, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'author', 'i', 'i-meta-annotation']],
#     [['Tinto,', 174, 179, 26, 6, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'author', 'i', 'i-meta-annotation']],
#     [['Origini', 181, 187, 27, 6, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['del', 189, 191, 28, 6, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['corsivo', 193, 199, 29, 6, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['nella', 202, 206, 30, 7, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['tipografia', 208, 217, 31, 7, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['italiana', 219, 226, 32, 7, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['del', 228, 230, 33, 7, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['Cinquecento,', 232, 243, 34, 7, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['Milano,', 246, 252, 35, 8, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'publicationplace', 'i', 'i-meta-annotation']],
#     [['Il', 254, 255, 36, 8, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'publisher', 'i', 'i-meta-annotation']],
#     [['Polifilo', 257, 264, 37, 8, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'publisher', 'i', 'i-meta-annotation']],
#     [['1967,', 266, 270, 38, 8, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'publicationyear', 'i', 'i-meta-annotation']],
#     [['pp.', 272, 274, 39, 8, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'pagination', 'i', 'i-meta-annotation']],
#     [['13-123.', 276, 282, 40, 8, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'pagination', 'e', 'e-meta-annotation']],
#     [['L.', 285, 286, 41, 9, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'author', 'b', 'b-secondary-full']],
#     [['Balsamo,', 288, 295, 42, 9, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'author', 'i', 'i-secondary-full']],
#     [['Produzione', 297, 306, 43, 9, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['e', 308, 308, 44, 9, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['circolazione', 310, 321, 45, 9, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['li-', 323, 325, 46, 9, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['braria', 328, 333, 47, 10, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['in', 335, 336, 48, 10, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['Emilia', 338, 343, 49, 10, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['(XV-XVIII', 345, 353, 50, 10, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['see.)', 355, 359, 51, 10, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['Studi', 362, 366, 52, 11, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['e', 368, 368, 53, 11, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['ricerche,', 370, 378, 54, 11, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['Parma,', 380, 385, 55, 11, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publicationplace', 'i', 'i-secondary-full']],
#     [['Casanova', 387, 394, 56, 11, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publisher', 'i', 'i-secondary-full']],
#     [['1983.', 397, 401, 57, 12, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publicationyear', 'e', 'e-secondary-full']],
#     [['F.', 404, 405, 58, 13, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'author', 'b', 'b-secondary-full']],
#     [['Barberi,', 407, 414, 59, 13, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'author', 'i', 'i-secondary-full']],
#     [['Il', 416, 417, 60, 13, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['frontespizio', 419, 430, 61, 13, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['nel', 432, 434, 62, 13, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['libro', 436, 440, 63, 13, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['ita-', 442, 445, 64, 13, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['liano', 448, 452, 65, 14, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['del', 454, 456, 66, 14, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['Quattrocento', 458, 469, 67, 14, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['e', 471, 471, 68, 14, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['del', 473, 475, 69, 14, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['Cinquecento,', 477, 488, 70, 14, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['Milano,', 491, 497, 71, 15, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publicationplace', 'i', 'i-secondary-full']],
#     [['Il', 499, 500, 72, 15, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publisher', 'i', 'i-secondary-full']],
#     [['Polifilo', 502, 509, 73, 15, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publisher', 'i', 'i-secondary-full']],
#     [['1969.', 511, 515, 74, 15, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publicationyear', 'e', 'e-secondary-full']],
#     [['F.', 518, 519, 75, 16, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'author', 'b', 'b-secondary-full']],
#     [['Barberi,', 521, 528, 76, 16, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'author', 'i', 'i-secondary-full']],
#     [['Il', 530, 531, 77, 16, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['libro', 533, 537, 78, 16, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['a', 539, 539, 79, 16, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['stampa,', 541, 547, 80, 16, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['Roma,', 549, 553, 81, 16, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publicationplace', 'i', 'i-secondary-full']],
#     [['Cur-', 555, 558, 82, 16, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publisher', 'i', 'i-secondary-full']],
#     [['do', 561, 562, 83, 17, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publisher', 'i', 'i-secondary-full']],
#     [['1965.', 564, 568, 84, 17, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publicationyear', 'e', 'e-secondary-full']],
#     [['F.', 571, 572, 85, 18, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'author', 'b', 'b-secondary-full']],
#     [['Barbier,', 574, 581, 86, 18, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'author', 'i', 'i-secondary-full']],
#     [['Trois', 583, 587, 87, 18, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['cent', 589, 592, 88, 18, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['ans', 594, 596, 89, 18, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['de', 598, 599, 90, 18, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['librairie', 601, 609, 91, 18, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['et', 611, 612, 92, 18, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['d’imprimerie.', 615, 627, 93, 19, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['Berger-Levrault.', 629, 644, 94, 19, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['1676-', 646, 650, 95, 19, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['1830,', 653, 657, 96, 20, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['Genève,', 659, 665, 97, 20, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publicationplace', 'i', 'i-secondary-full']],
#     [['Librairie', 667, 675, 98, 20, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publisher', 'i', 'i-secondary-full']],
#     [['Droz', 677, 680, 99, 20, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publisher', 'i', 'i-secondary-full']],
#     [['1979.', 682, 686, 100, 20, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publicationyear', 'e', 'e-secondary-full']],
#     [['U.', 689, 690, 101, 21, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'author', 'b', 'b-meta-annotation']],
#     [['Baroncelli,', 692, 702, 102, 21, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'author', 'i', 'i-meta-annotation']],
#     [['Editori', 704, 710, 103, 21, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['e', 712, 712, 104, 21, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['stampatori', 714, 723, 105, 21, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['a', 725, 725, 106, 21, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['Brescia', 728, 734, 107, 22, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['nel', 736, 738, 108, 22, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['Cinquecento,', 740, 751, 109, 22, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['in:', 753, 755, 110, 22, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'conjunction', 'i', 'i-meta-annotation']],
#     [['Studi', 757, 761, 111, 22, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['di', 763, 764, 112, 22, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['bi-', 766, 768, 113, 22, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['blioteconomia', 771, 783, 114, 23, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['e', 785, 785, 115, 23, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['storia', 787, 792, 116, 23, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['del', 794, 796, 117, 23, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['libro', 798, 802, 118, 23, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['in', 804, 805, 119, 23, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['onore', 807, 811, 120, 23, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['di', 814, 815, 121, 24, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['Francesco', 817, 825, 122, 24, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['Barberi,', 827, 834, 123, 24, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['Roma,', 836, 840, 124, 24, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'publicationplace', 'i', 'i-meta-annotation']],
#     [['A.I.B.', 842, 847, 125, 24, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'publisher', 'i', 'i-meta-annotation']],
#     [['1976,', 850, 854, 126, 25, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'publicationyear', 'i', 'i-meta-annotation']],
#     [['pp.', 856, 858, 127, 25, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'pagination', 'i', 'i-meta-annotation']],
#     [['97-107.', 860, 866, 128, 25, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'pagination', 'e', 'e-meta-annotation']],
#     [['U.', 869, 870, 129, 26, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'author', 'b', 'b-secondary-full']],
#     [['Baroncelli,', 872, 882, 130, 26, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'author', 'i', 'i-secondary-full']],
#     [['La', 884, 885, 131, 26, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['stampa', 887, 892, 132, 26, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['nella', 894, 898, 133, 26, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['Riviera', 900, 906, 134, 26, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['bresciana', 909, 917, 135, 27, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['del', 919, 921, 136, 27, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['Garda', 923, 927, 137, 27, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['nei', 929, 931, 138, 27, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['secoli', 933, 938, 139, 27, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['XV', 940, 941, 140, 27, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['e', 943, 943, 141, 27, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['XVI.', 945, 948, 142, 27, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['Edizioni', 951, 958, 143, 28, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publisher', 'i', 'i-secondary-full']],
#     [['dell’Ateneo', 960, 970, 144, 28, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publisher', 'i', 'i-secondary-full']],
#     [['di', 972, 973, 145, 28, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publisher', 'i', 'i-secondary-full']],
#     [['Salò', 975, 978, 146, 28, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publisher', 'i', 'i-secondary-full']],
#     [['nel', 980, 982, 147, 28, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publisher', 'i', 'i-secondary-full']],
#     [['IV', 984, 985, 148, 28, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publisher', 'i', 'i-secondary-full']],
#     [['cen-', 987, 990, 149, 28, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publisher', 'i', 'i-secondary-full']],
#     [['tenario', 993, 999, 150, 29, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publisher', 'i', 'i-secondary-full']],
#     [['della', 1001, 1005, 151, 29, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publisher', 'i', 'i-secondary-full']],
#     [['sua', 1007, 1009, 152, 29, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publisher', 'i', 'i-secondary-full']],
#     [['fondazione', 1011, 1020, 153, 29, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publisher', 'i', 'i-secondary-full']],
#     [['1564-1964,', 1022, 1031, 154, 29, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publisher', 'i', 'i-secondary-full']],
#     [['Brescia,', 1034, 1041, 155, 30, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publicationplace', 'i', 'i-secondary-full']],
#     [['Ateneo', 1043, 1048, 156, 30, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publisher', 'i', 'i-secondary-full']],
#     [['(tip.', 1050, 1054, 157, 30, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publisher', 'i', 'i-secondary-full']],
#     [['Geraldi)', 1056, 1063, 158, 30, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publisher', 'i', 'i-secondary-full']],
#     [['1964.', 1065, 1069, 159, 30, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publicationyear', 'e', 'e-secondary-full']],
#     [['R.', 1072, 1073, 160, 31, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'author', 'b', 'b-secondary-full']],
#     [['Bertieri,', 1075, 1083, 161, 31, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'author', 'i', 'i-secondary-full']],
#     [['Editori', 1085, 1091, 162, 31, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['e', 1093, 1093, 163, 31, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['stampatori', 1095, 1104, 164, 31, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['italiani', 1106, 1113, 165, 31, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['del', 1116, 1118, 166, 32, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['Quattrocento,', 1120, 1132, 167, 32, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['Milano,', 1134, 1140, 168, 32, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publicationplace', 'i', 'i-secondary-full']],
#     [['Hoepli', 1142, 1147, 169, 32, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publisher', 'i', 'i-secondary-full']],
#     [['1929.', 1149, 1153, 170, 32, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publicationyear', 'e', 'e-secondary-full']],
#     [['G.', 1156, 1157, 171, 33, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'author', 'b', 'b-secondary-full']],
#     [['Boffito,', 1159, 1166, 172, 33, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'author', 'i', 'i-secondary-full']],
#     [['Iniziali', 1168, 1175, 173, 33, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['istoriate', 1177, 1185, 174, 33, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['e', 1187, 1187, 175, 33, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['iniziali', 1189, 1196, 176, 33, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['fiorite', 1199, 1205, 177, 34, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['o', 1207, 1207, 178, 34, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['arabescate,', 1209, 1219, 179, 34, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['Firenze,', 1221, 1228, 180, 34, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publicationplace', 'i', 'i-secondary-full']],
#     [['Libreria', 1230, 1237, 181, 34, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publisher', 'i', 'i-secondary-full']],
#     [['in-', 1239, 1241, 182, 34, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publisher', 'i', 'i-secondary-full']],
#     [['temazionale', 1244, 1254, 183, 35, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publisher', 'i', 'i-secondary-full']],
#     [['Seeber', 1256, 1261, 184, 35, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publisher', 'i', 'i-secondary-full']],
#     [['(tip.', 1263, 1267, 185, 35, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publisher', 'i', 'i-secondary-full']],
#     [['Giuntina)', 1269, 1277, 186, 35, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publisher', 'i', 'i-secondary-full']],
#     [['1925.', 1280, 1284, 187, 36, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publicationyear', 'e', 'e-secondary-full']],
#     [['Rist.,', 1286, 1291, 188, 36, 'CFI0056764'],
#      [False, False, ''],
#      ['', '', 'o', 'o']],
#     [['Torino,', 1293, 1299, 189, 36, 'CFI0056764'],
#      [False, False, ''],
#      ['', '', 'o', 'o']],
#     [['Bottega', 1301, 1307, 190, 36, 'CFI0056764'],
#      [False, False, ''],
#      ['', '', 'o', 'o']],
#     [['d’Era-', 1309, 1314, 191, 36, 'CFI0056764'],
#      [False, False, ''],
#      ['', '', 'o', 'o']],
#     [['C.', 1328, 1329, 194, 38, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'author', 'b', 'b-secondary-full']],
#     [['Castellani,', 1331, 1341, 195, 38, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'author', 'i', 'i-secondary-full']],
#     [['La', 1343, 1344, 196, 38, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['stampa', 1346, 1351, 197, 38, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['in', 1353, 1354, 198, 38, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['Venezia', 1356, 1362, 199, 38, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['dalla', 1365, 1369, 200, 39, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['sua', 1371, 1373, 201, 39, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['origine', 1375, 1381, 202, 39, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['alla', 1383, 1386, 203, 39, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['morte', 1388, 1392, 204, 39, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['di', 1394, 1395, 205, 39, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['Aldo', 1397, 1400, 206, 39, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['Ma-', 1402, 1404, 207, 39, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['nuzio', 1407, 1411, 208, 40, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['Seniore,', 1413, 1420, 209, 40, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['Venezia,', 1422, 1429, 210, 40, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publicationplace', 'i', 'i-secondary-full']],
#     [['Ongania', 1431, 1437, 211, 40, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publisher', 'i', 'i-secondary-full']],
#     [['1889.', 1439, 1443, 212, 40, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publicationyear', 'e', 'e-secondary-full']],
#     [['R.', 1474, 1475, 217, 42, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'author', 'b', 'b-meta-annotation']],
#     [['Chartier-D.', 1477, 1487, 218, 42, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'author', 'i', 'i-meta-annotation']],
#     [['Roche,', 1489, 1494, 219, 42, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'author', 'i', 'i-meta-annotation']],
#     [['Le', 1496, 1497, 220, 42, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['livre:', 1499, 1504, 221, 42, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['un', 1506, 1507, 222, 42, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['changement', 1510, 1519, 223, 43, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['de', 1521, 1522, 224, 43, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['perspective,', 1524, 1535, 225, 43, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['in:', 1537, 1539, 226, 43, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'conjunction', 'i', 'i-meta-annotation']],
#     [['Faire', 1541, 1545, 227, 43, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['de', 1547, 1548, 228, 43, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['l’histoire,', 1551, 1561, 229, 44, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['a', 1563, 1563, 230, 44, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'editor', 'i', 'i-meta-annotation']],
#     [['cura', 1565, 1568, 231, 44, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'editor', 'i', 'i-meta-annotation']],
#     [['di', 1570, 1571, 232, 44, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'editor', 'i', 'i-meta-annotation']],
#     [['J.', 1573, 1574, 233, 44, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'editor', 'i', 'i-meta-annotation']],
#     [['Le', 1576, 1577, 234, 44, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'editor', 'i', 'i-meta-annotation']],
#     [['Goffi', 1579, 1583, 235, 44, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'editor', 'i', 'i-meta-annotation']],
#     [['e', 1585, 1585, 236, 44, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'editor', 'i', 'i-meta-annotation']],
#     [['P.', 1587, 1588, 237, 44, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'editor', 'i', 'i-meta-annotation']],
#     [['Nora,', 1591, 1595, 238, 45, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'editor', 'i', 'i-meta-annotation']],
#     [['III,', 1597, 1600, 239, 45, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'volume', 'i', 'i-meta-annotation']],
#     [['Paris,', 1602, 1607, 240, 45, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'publicationplace', 'i', 'i-meta-annotation']],
#     [['Gallimard', 1609, 1617, 241, 45, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'publisher', 'i', 'i-meta-annotation']],
#     [['1974.', 1619, 1623, 242, 45, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'publicationyear', 'e', 'e-meta-annotation']],
#     [['T.', 1626, 1627, 243, 46, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'author', 'b', 'b-secondary-full']],
#     [['F.', 1629, 1630, 244, 46, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'author', 'i', 'i-secondary-full']],
#     [['Dibdin,', 1632, 1638, 245, 46, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'author', 'i', 'i-secondary-full']],
#     [['The', 1640, 1642, 246, 46, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['bibliographical', 1644, 1658, 247, 46, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['Deca-', 1660, 1664, 248, 46, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['meron,', 1667, 1672, 249, 47, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['II', 1674, 1675, 250, 47, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publicationspecifications', 'i', 'i-secondary-full']],
#     [['e', 1677, 1677, 251, 47, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publicationspecifications', 'i', 'i-secondary-full']],
#     [['III,', 1679, 1682, 252, 47, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publicationspecifications', 'i', 'i-secondary-full']],
#     [['London,', 1684, 1690, 253, 47, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publicationplace', 'i', 'i-secondary-full']],
#     [['Bulmer', 1692, 1697, 254, 47, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publisher', 'i', 'i-secondary-full']],
#     [['1817.', 1699, 1703, 255, 47, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publicationyear', 'e', 'e-secondary-full']],
#     [['L.', 1706, 1707, 256, 48, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'author', 'b', 'b-meta-annotation']],
#     [['Donati,', 1709, 1715, 257, 48, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'author', 'i', 'i-meta-annotation']],
#     [['Le', 1717, 1718, 258, 48, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['vicende', 1720, 1726, 259, 48, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['del', 1728, 1730, 260, 48, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['fior', 1732, 1735, 261, 48, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['di', 1737, 1738, 262, 48, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['virtù,', 1740, 1745, 263, 48, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['«La', 1748, 1750, 264, 49, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['Bibliofilia»,', 1752, 1764, 265, 49, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['LXXVI,', 1766, 1771, 266, 49, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'publicationnumber-year', 'i', 'i-meta-annotation']],
#     [['1974,', 1773, 1777, 267, 49, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'publicationnumber-year', 'i', 'i-meta-annotation']],
#     [['pp.', 1780, 1782, 268, 50, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'pagination', 'i', 'i-meta-annotation']],
#     [['175-208.', 1784, 1791, 269, 50, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'pagination', 'e', 'e-meta-annotation']],
#     [['L.', 1794, 1795, 270, 51, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'author', 'b', 'b-secondary-full']],
#     [['Donati,', 1797, 1803, 271, 51, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'author', 'i', 'i-secondary-full']],
#     [['Riflessioni', 1805, 1815, 272, 51, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['sulle', 1817, 1821, 273, 51, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['marche', 1823, 1828, 274, 51, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['tipo-', 1830, 1834, 275, 51, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['grafiche,', 1837, 1845, 276, 52, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['Bellinzona,', 1847, 1857, 277, 52, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publicationplace', 'i', 'i-secondary-full']],
#     [['S.', 1859, 1860, 278, 52, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publisher', 'i', 'i-secondary-full']],
#     [['A.', 1862, 1863, 279, 52, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publisher', 'i', 'i-secondary-full']],
#     [['Grassi', 1865, 1870, 280, 52, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publisher', 'i', 'i-secondary-full']],
#     [['&', 1872, 1872, 281, 52, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publisher', 'i', 'i-secondary-full']],
#     [['Co.', 1875, 1877, 282, 53, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publisher', 'i', 'i-secondary-full']],
#     [['1959', 1879, 1882, 283, 53, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publicationyear', 'e', 'e-secondary-full']],
#     [['(«', 1884, 1885, 284, 53, 'CFI0056764'],
#      [False, False, ''],
#      ['', '', 'o', 'o']],
#     [['Edizioni', 1887, 1894, 285, 53, 'CFI0056764'],
#      [False, False, ''],
#      ['', '', 'o', 'o']],
#     [['Società', 1896, 1902, 286, 53, 'CFI0056764'],
#      [False, False, ''],
#      ['', '', 'o', 'o']],
#     [['Guten-', 1904, 1909, 287, 53, 'CFI0056764'],
#      [False, False, ''],
#      ['', '', 'o', 'o']],
#     [['L.', 1928, 1929, 292, 55, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'author', 'b', 'b-secondary-full']],
#     [['Febvre', 1931, 1936, 293, 55, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'author', 'i', 'i-secondary-full']],
#     [['-', 1938, 1938, 294, 55, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'author', 'i', 'i-secondary-full']],
#     [['H.', 1940, 1941, 295, 55, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'author', 'i', 'i-secondary-full']],
#     [['J.', 1943, 1944, 296, 55, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'author', 'i', 'i-secondary-full']],
#     [['Martin,', 1946, 1952, 297, 55, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'author', 'i', 'i-secondary-full']],
#     [['La', 1954, 1955, 298, 55, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['nascita', 1957, 1963, 299, 55, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['del', 1965, 1967, 300, 55, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['libro,', 1970, 1975, 301, 56, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['Bari,', 1977, 1981, 302, 56, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publicationplace', 'i', 'i-secondary-full']],
#     [['Laterza', 1983, 1989, 303, 56, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publisher', 'i', 'i-secondary-full']],
#     [['1977,', 1991, 1995, 304, 56, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publicationyear', 'i', 'i-secondary-full']],
#     [['2', 1997, 1997, 305, 56, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publicationspecifications', 'i', 'i-secondary-full']],
#     [['voli.', 1999, 2003, 306, 56, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publicationspecifications', 'e', 'e-secondary-full']],
#     [['R.', 2045, 2046, 313, 58, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'author', 'b', 'b-meta-annotation']],
#     [['Fulin,', 2048, 2053, 314, 58, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'author', 'i', 'i-meta-annotation']],
#     [['Documenti', 2055, 2063, 315, 58, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['per', 2065, 2067, 316, 58, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['servire', 2069, 2075, 317, 58, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['alla', 2077, 2080, 318, 58, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['storia', 2082, 2087, 319, 58, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['della', 2090, 2094, 320, 59, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['tipografia', 2096, 2105, 321, 59, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['veneziana,', 2107, 2116, 322, 59, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['«', 2118, 2118, 323, 59, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['Archivio', 2120, 2127, 324, 59, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['veneto', 2130, 2135, 325, 60, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['»,', 2137, 2138, 326, 60, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'title', 'i', 'i-meta-annotation']],
#     [['XÏÏ,', 2140, 2143, 327, 60, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'publicationnumber-year', 'i', 'i-meta-annotation']],
#     [['1882,', 2145, 2149, 328, 60, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'publicationnumber-year', 'i', 'i-meta-annotation']],
#     [['t.', 2151, 2152, 329, 60, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'tomo', 'i', 'i-meta-annotation']],
#     [['ΧΧΙΠ,', 2154, 2158, 330, 60, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'tomo', 'i', 'i-meta-annotation']],
#     [['pp.', 2160, 2162, 331, 60, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'pagination', 'i', 'i-meta-annotation']],
#     [['84-', 2164, 2166, 332, 60, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'pagination', 'i', 'i-meta-annotation']],
#     [['212.', 2169, 2172, 333, 61, 'CFI0056764'],
#      [False, False, ''],
#      ['meta-annotation', 'pagination', 'e', 'e-meta-annotation']],
#     [['G.', 2175, 2176, 334, 62, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'author', 'b', 'b-secondary-full']],
#     [['Fumagalli,', 2178, 2187, 335, 62, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'author', 'i', 'i-secondary-full']],
#     [['Lexicon', 2189, 2195, 336, 62, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['typographicum', 2197, 2209, 337, 62, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['Italiae.', 2212, 2219, 338, 63, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['Dictionnaire', 2221, 2232, 339, 63, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['géographique', 2234, 2245, 340, 63, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['d’Italie', 2247, 2254, 341, 63, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['pour', 2257, 2260, 342, 64, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['servir', 2262, 2267, 343, 64, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['à', 2269, 2269, 344, 64, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['l’histoire', 2271, 2280, 345, 64, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['de', 2282, 2283, 346, 64, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['l’imprimerie', 2285, 2296, 347, 64, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['dans', 2298, 2301, 348, 64, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['ce', 2304, 2305, 349, 65, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['pays,', 2307, 2311, 350, 65, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'title', 'i', 'i-secondary-full']],
#     [['Firenze', 2313, 2319, 351, 65, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publicationplace', 'i', 'i-secondary-full']],
#     [['1905.', 2321, 2325, 352, 65, 'CFI0056764'],
#      [False, False, ''],
#      ['secondary-full', 'publicationyear', 'e', 'e-secondary-full']],
#     [['Supplementi', 2327, 2337, 353, 65, 'CFI0056764'],
#      [False, False, ''],
#      ['', '', 'o', 'o']]],
#    'page_id': 'CFI0056764--page-0002',
#    'single_page_file_number': 2}}}

# %% [markdown]
# Tag consolidation to remove unfrequently used tags

# %%
# Specific Tag consolidation
correspondances = {
    'abbreviatedtitle': 'title', #
    'abbreviation': 'abbreviation', 
    'appendix': 'ref', #
    'archivalfond': 'archivalreference', #
    'archivalreference': 'archivalreference',
    'archivalseries': 'archivalreference', #
    'archivalunit': 'archivalreference', #
    'archive': 'archive_lib', #
    'attachment': 'attachment',
    'author': 'author',
    'box': 'box',
    'cartulation': 'cartulation', 
    'cedola': 'ref', #
    'century': 'date', #
    'chapter': 'ref', #
    'citation': 'ref', #
    'codex': 'archivalreference', #
    'column': 'column',
    'conjunction': 'conjunction', 
    'curator': 'author', #
    'date': 'date', 
    'editor': 'author', #
    'fascicolo': 'folder', #
    'filza': 'filza',
    'folder': 'folder',
    'foliation': 'foliation',
    'fond': 'archivalreference', #
    'implicit': '',
    'library': 'archive_lib', #
    'mazzo': 'ref', #
    'notary': 'archivalreference', #
    'note': 'numbered_ref', #
    'numbering': 'numbered_ref', #
    'other': '', #
    'pagination': 'pagination',
    'parchment': 'ref', #
    'period': 'date', #
    'protocollo': 'ref', #
    'parte': 'ref', #
    'publicationnumber': 'publicationnumber-year', #
    'publicationnumber-year': 'publicationnumber-year',
    'publicationplace': 'publicationplace',
    'publicationspecifications': 'publicationspecifications',
    'publicationyear': 'year', #
    'publisher': 'publisher',
    'registry': 'registry',
    'responsible': 'author', #
    'series': 'series',
    'table': 'ref', #
    'title': 'title',
    'tomo': 'tomo',
    'topicdate': 'publicationplace', #
    'voce': 'ref', #
    'volume': 'volume',
    'website': 'ref', #
    'year': 'year',
    '': ''
}

# define supporting functions
window = 2 # the window of dependance for the CRFs: use plus and minus that number as a context
from code.feature_extraction_words import word2features, generate_featuresLight
def text2features(text):
    return [word2features(text, i, window = window) for i in range(len(text))]
def text2featuresL(text):
    return [word2features(text, i, window = window, feature_function=generate_featuresLight) for i in range(len(text))]

# create beginend tags Y
def text2labelsBE(text):
    return [token[2][2] for token in text]

# create tagged-beginend tags Y
def text2labelsTBE(text):
    return [token[2][3] for token in text]

# create specific tags Y
def text2labelsS(text):
    return [correspondances[token[2][1]] for token in text]

# %%
# prepare annotated data for CRF
annotated_data = list()
for doc in data:
    doc_data_ann = list()
    for page in doc["pages"].values():
        if page["is_annotated"]:
            doc_data_ann.extend(page["offsets"])
    if len(doc_data_ann) > 0:
        annotated_data.append(doc_data_ann)
print(len(annotated_data))
print(len(data))

# %%
# %%time
# Define train and test sets
d = [text2features(text) for text in annotated_data]
l = [text2labelsS(text) for text in annotated_data]
l_tbe = [text2labelsTBE(text) for text in annotated_data]
# Clean tag space
labels_to_keep = list(set([x for y in l for x in y]))
labels_to_keep_tbe = list(set([x for y in l_tbe for x in y]))

random_state = np.random.RandomState(0)
    
# VALIDATION set
X_rest, X_valid, y_rest, y_valid = train_test_split(d, l, test_size=0.1, random_state=random_state)
# TRAIN/TEST
X_train, X_test, y_train, y_test = train_test_split(X_rest, y_rest, test_size=0.25, random_state=random_state)

# %%
# Count labels
counts = {x:0 for x in labels_to_keep}
for c in counts.keys():
    counts[c] = len([x for y in l for x in y if x==c])
print(counts)
counts = {x:0 for x in labels_to_keep_tbe}
for c in counts.keys():
    counts[c] = len([x for y in l_tbe for x in y if x==c])
print(counts)

# %%
# An example use of CRFs
crf = sklearn_crfsuite.CRF( 
    algorithm='lbfgs',
    c1=0.1,
    c2=0.1,
    max_iterations=100,
    all_possible_transitions=False
)
crf.fit(X_train, y_train)
y_pred = crf.predict(X_test)
print(metrics.flat_classification_report(
    y_test, y_pred, labels=labels_to_keep, digits=3
))

# %%
# %%time
# Parameters search
crf = sklearn_crfsuite.CRF( 
    max_iterations=100,
    algorithm = 'lbfgs',
    all_possible_transitions=False
)
params_space = {
    'c1': scipy.stats.expon(scale=0.5),
    'c2': scipy.stats.expon(scale=0.05)
}

from code.support_functions import BER
scorer = make_scorer(metrics.flat_f1_score, 
                        average='weighted', labels=labels_to_keep)
#scorer = make_scorer(BER, greater_is_better=True)
    
# search
rs = RandomizedSearchCV(crf, params_space, 
                        cv=3, 
                        verbose=1, 
                        n_jobs=-10, 
                        n_iter=5, 
                        scoring=scorer)
rs.fit(X_train, y_train)

# %%
print('best params:', rs.best_params_)
print('best CV score:', rs.best_score_)

# %%
# classification report
crf = rs.best_estimator_
y_pred = crf.predict(X_test)
print(metrics.flat_classification_report(
    y_test, y_pred, labels=labels_to_keep, digits=3
))

# Confusion matrices
from code.support_functions import flatten_predictions

print(confusion_matrix(flatten_predictions(y_test), flatten_predictions(y_pred), labels=labels_to_keep))
plt.imshow(np.log(confusion_matrix(flatten_predictions(y_test), flatten_predictions(y_pred), labels=labels_to_keep)),
           cmap='Blues', interpolation='nearest')
plt.grid(False)
plt.ylabel('Ground truth', fontsize=16)
plt.xlabel('Predicted', fontsize=16)
plt.xticks(np.arange(0, len(labels_to_keep), 1))
plt.yticks(np.arange(0, len(labels_to_keep), 1))
plt.title("Confusion Matrix Model 1", fontsize=16)

# %%
# K-fold validation
from support_functions import BER
scorer = make_scorer(metrics.flat_f1_score, 
                        average='weighted', labels=labels_to_keep)
scorer2 = make_scorer(BER, greater_is_better=True)

# plug here your params, or use rs.best_params_
crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs',
    # the parameters used for the results reported in the publication
    c2= 0.067592883332507694, c1= 0.37774963191685329,
    max_iterations=200, 
    all_possible_transitions=True
)
k = 5

cv = cross_val_score(crf, X_rest, y_rest, cv=k, scoring=scorer, n_jobs=-2)
print("%d-fold validation mean: "%k,cv.mean())
cv = cross_val_score(crf, X_rest, y_rest, cv=k, scoring=scorer2, n_jobs=-2)
print("%d-fold validation mean: "%k,cv.mean())

# %%
# Learning curves
# Watch out, this takes up a lot of primary memory
from code.support_functions import plot_learning_curve

# Slices of data for learning curves
train_sizes=np.linspace(0.1, 1.0, 10)
title = "Learning Curves for Model 1"
message = "M1"
# Cross validation scheme with 80-20 splits and 3 iterations per train data size (to evaluate variance)
cv = model_selection.ShuffleSplit(test_size=0.2, random_state=0)
estimator = sklearn_crfsuite.CRF(
    algorithm='lbfgs',
    c2= 0.067592883332507694, c1= 0.37774963191685329,
    max_iterations=100, 
    all_possible_transitions=False
)
plot_learning_curve(estimator, title, X_rest, y_rest, labels_to_keep, cv=cv, train_sizes=train_sizes, n_jobs=20, message=message)

# %%
# VALIDATION
# %%time

crf = sklearn_crfsuite.CRF( 
    algorithm='lbfgs',
    c2= 0.067592883332507694, c1= 0.37774963191685329,
    max_iterations=500,
    all_possible_transitions=True
)
crf.fit(X_rest, y_rest)
y_pred = crf.predict(X_valid)
print(metrics.flat_classification_report(
    y_valid, y_pred, labels=labels_to_keep, digits=3
))

# %%
# Train final models for task 1
crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs',
    c2= 0.067592883332507694, c1= 0.37774963191685329,
    max_iterations=500, 
    all_possible_transitions=True
)
crf.fit(d, l)

# save model
#joblib.dump(crf,'models/modelM1_ALL_L.pkl')

# %% [markdown]
# Apply model to new data.
# This is needed if you want to use the results from the first parser as features for the second one.

# %%
# load model
crf1 = joblib.load('models/modelM1_ALL_L.pkl')

# %%
def process_document(doc):
    for page in doc["pages"].values():
        if not page["is_annotated"]:
            data_to_tag = [text2features(page["offsets"])]
            page_lab = crf1.predict(data_to_tag)
            assert len(page_lab[0]) == len(page["offsets"])
            page.update({"specific_tags":page_lab[0]})
        else:
            page.update({"specific_tags":text2labelsS(page["offsets"])})
    return doc
            
threads = Pool(45)

# %%
# parse all
data2 = list()
for ar in threads.imap_unordered(process_document, data):
    data2.append(ar)

# %%
pickle.dump(data2, open("dataset/data.p", "wb"))
